# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Dataset/WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7032.000000  7032.000000     7032.000000   7032.000000
# mean        0.162400    32.421786       64.798208   2283.300441
# std         0.368844    24.545260       30.085974   2266.771362
# min         0.000000     1.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.587500    401.450000
# 50%         0.000000    29.000000       70.350000   1397.475000
# 75%         0.000000    55.000000       89.862500   3794.737500
# max         1.000000    72.000000      118.750000   8684.800000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7032 entries, 0 to 7031
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7032 non-null   object
#  1   gender            7032 non-null   object
#  2   SeniorCitizen     7032 non-null   int64
#  3   Partner           7032 non-null   object
#  4   Dependents        7032 non-null   object
#  5   tenure            7032 non-null   int64
#  6   PhoneService      7032 non-null   object
#  7   MultipleLines     7032 non-null   object
#  8   InternetService   7032 non-null   object
#  9   OnlineSecurity    7032 non-null   object
#  10  OnlineBackup      7032 non-null   object
#  11  DeviceProtection  7032 non-null   object
#  12  TechSupport       7032 non-null   object
#  13  StreamingTV       7032 non-null   object
#  14  StreamingMovies   7032 non-null   object
#  15  Contract          7032 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
col = ['gender', 'SeniorCitizen', 'Partner', 'Dependents',
       'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
       'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn']

# %%
col
# Out:
# ['gender',
#  'SeniorCitizen',
#  'Partner',
#  'Dependents',
#  'tenure',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'MonthlyCharges',
#  'TotalCharges',
#  'Churn']

# %% [markdown]
# ##Data preprocessing

# %%
from sklearn.preprocessing import LabelEncoder

# %%
temp_col = ['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
       'PaymentMethod', 'Churn']

# %%
le = LabelEncoder()

# %%
updated_df = df.copy()
for i in temp_col:
  updated_df[i] = le.fit_transform(df[i])

# %%
updated_df.head()
# Out:
#    customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0  7590-VHVEG       0              0        1           0       1
# 1  5575-GNVDE       1              0        0           0      34
# 2  3668-QPYBK       1              0        0           0       2
# 3  7795-CFOCW       1              0        0           0      45
# 4  9237-HQITU       0              0        0           0       2
#
#    PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# 0             0              1                0               0  ...
# 1             1              0                0               2  ...
# 2             1              0                0               2  ...
# 3             0              1                0               2  ...
# 4             1              0                1               0  ...
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 0            0            0                0         0
# ...

# %% [markdown]
# ##Visualizations

# %%
plt.figure(figsize=(18,18))
for i in range(len(col)):
  plt.subplot(6,4,i+1)
  sns.distplot(updated_df[col[i]], kde = False)
plt.show()

# %%
df_0 = updated_df[updated_df.Churn == 0]
df_0.head()
# Out:
#    customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0  7590-VHVEG       0              0        1           0       1
# 1  5575-GNVDE       1              0        0           0      34
# 3  7795-CFOCW       1              0        0           0      45
# 6  1452-KIOVK       1              0        0           1      22
# 7  6713-OKOMC       0              0        0           0      10
#
#    PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# 0             0              1                0               0  ...
# 1             1              0                0               2  ...
# 3             0              1                0               2  ...
# 6             1              2                1               0  ...
# 7             0              1                0               2  ...
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 0            0            0                0         0
# ...

# %%
df_1 = updated_df[updated_df.Churn == 1]
df_1.head()
# Out:
#     customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 2   3668-QPYBK       1              0        0           0       2
# 4   9237-HQITU       0              0        0           0       2
# 5   9305-CDSKC       0              0        0           0       8
# 8   7892-POOKP       0              0        1           0      28
# 13  0280-XJGEX       1              0        0           0      49
#
#     PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# 2              1              0                0               2  ...
# 4              1              0                1               0  ...
# 5              1              2                1               0  ...
# 8              1              2                1               0  ...
# 13             1              2                1               0  ...
#
#     DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# ...

# %%
plt.figure(figsize=(20,20))
for i in range(len(col)):
  plt.subplot(6,4,i+1)
  sns.distplot(df_0[col[i]], kde = False, label = 'Customers in company')
  sns.distplot(df_1[col[i]], kde = False, label = 'Customers left company')
  plt.legend()
plt.show()

# %%
sns.pairplot(updated_df,hue='Churn')

# %%
sns.countplot(x = 'Churn' ,data= updated_df)
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %%
updated_df.Churn.value_counts()
# Out:
# Churn
# 0    5163
# 1    1869
# Name: count, dtype: int64

# %%
len(col)
# Out:
# 20

# %%
x = updated_df.iloc[:, 1:20]
y = updated_df.iloc[:,20:]

# %%
x.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              0        1           0       1             0
# 1       1              0        0           0      34             1
# 2       1              0        0           0       2             1
# 3       1              0        0           0      45             0
# 4       0              0        0           0       2             1
#
#    MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 0              1                0               0             2
# 1              0                0               2             0
# 2              0                0               2             2
# 3              1                0               2             0
# 4              0                1               0             0
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 0            0            0                0         0
# ...

# %%
y.head()
# Out:
#    Churn
# 0      0
# 1      0
# 2      1
# 3      0
# 4      1

# %% [markdown]
# #Model Creation (Decision Tree Classifier)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.3, random_state = 60)

# %%
RF = RandomForestClassifier(n_estimators=20, random_state=0)

# %%
RF.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=20, random_state=0)

# %%
predicted_values = RF.predict(x_test)

# %%
predicted_values
# Out:
# array([1, 0, 1, ..., 0, 1, 0])

# %% [markdown]
# ##Model Evaluation

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
from sklearn import metrics

# %%
print(confusion_matrix(y_test,predicted_values))
# Out:
# [[1415  153]
#  [ 307  235]]

# %%
print("Accuracy Score : ", round(accuracy_score(y_test,predicted_values)*100),'%')
print("Precision Score : ", round(precision_score(y_test,predicted_values)*100),'%')
print("F1 Score : ", round(f1_score(y_test,predicted_values)*100),'%')
print("Recall Score : ", round(recall_score(y_test,predicted_values)*100),'%')
# Out:
# Accuracy Score :  78 %
# Precision Score :  61 %
# F1 Score :  51 %
# Recall Score :  43 %

# %%
print(classification_report(y_test,predicted_values))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.90      0.86      1568
#            1       0.61      0.43      0.51       542
#
#     accuracy                           0.78      2110
#    macro avg       0.71      0.67      0.68      2110
# weighted avg       0.77      0.78      0.77      2110

# %% [markdown]
# # **Saving trained Random Forest model**

# %%
import pickle

RF_pkl_filename = '/content/drive/MyDrive/Project/model.pkl'

RF_Model_pkl = open(RF_pkl_filename, 'wb')
pickle.dump(RF, RF_Model_pkl)

RF_Model_pkl.close()

# %% [markdown]
# # **Inferencing Model**

# %%
churn_class = ['No', 'Yes']

# %%
import pickle
RF_model = pickle.load(open('/content/drive/MyDrive/Project/model.pkl', 'rb'))

# %%
data = np.array([[1, 0, 0, 0, 2, 1, 0, 0, 2, 2, 0, 0, 0, 0, 0, 1, 3, 53.85, 108.15]])
prediction = RF_model.predict(data)
print(churn_class[prediction[0]])
# Out:
# Yes
